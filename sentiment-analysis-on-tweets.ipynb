# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from time import time
import random
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras import models,layers
from tensorflow import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../input/sentiment140/training.1600000.processed.noemoticon.csv", encoding = "ISO-8859-1",header = None)
df.columns = ['labels','time','date','qurey','username','tweet']
df.head(10)
# Out:
#    labels        time                          date     qurey  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 5       0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY
# 6       0  1467811592  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
# 7       0  1467811594  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
# 8       0  1467811795  Mon Apr 06 22:20:05 PDT 2009  NO_QUERY
# 9       0  1467812025  Mon Apr 06 22:20:09 PDT 2009  NO_QUERY
#
#           username                                              tweet
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....
# 5         joy_wolf                      @Kwesidei not the whole crew
# 6          mybirch                                        Need a hug
# 7             coZZ  @LOLTrish hey  long time no see! Yes.. Rains a...
# 8  2Hood4Hollywood               @Tatiana_K nope they didn't have it
# 9          mimismo                          @twittera que me muera ?

# %%
df.describe()
# Out:
#              labels          time
# count  1.600000e+06  1.600000e+06
# mean   2.000000e+00  1.998818e+09
# std    2.000001e+00  1.935761e+08
# min    0.000000e+00  1.467810e+09
# 25%    0.000000e+00  1.956916e+09
# 50%    2.000000e+00  2.002102e+09
# 75%    4.000000e+00  2.177059e+09
# max    4.000000e+00  2.329206e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600000 entries, 0 to 1599999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   labels    1600000 non-null  int64
#  1   time      1600000 non-null  int64
#  2   date      1600000 non-null  object
#  3   qurey     1600000 non-null  object
#  4   username  1600000 non-null  object
#  5   tweet     1600000 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 73.2+ MB

# %%
df.labels.value_counts()
# Out:
# 0    800000
# 4    800000
# Name: labels, dtype: int64

# %% [markdown]
# > df_pos is positive tweets and positive tweets labels is 4
# > df_neg is negative tweets and negative tweets labels is 0

# %%
df_pos = df[df['labels'] == 4]
df_neg = df[df['labels'] == 0]
print(len(df_pos), len(df_neg))
# Out:
# 800000 800000

# %% [markdown]
# # Preprocessing Dataset

# %% [markdown]
# # 1. Tokenization

# %%
data1=df[df['labels']==0].sample(2500)
data2=df[df['labels']==4].sample(2500)

# %%
df=data1.append(data2)

# %%
print(df.shape)
# Out:
# (5000, 6)

# %%
text = df.tweet.to_list()
token = Tokenizer()
token.fit_on_texts(text)

# %%
len(token.index_word)
# Out:
# 11588

# %%
vocab_size = len(token.word_index)+1
vocab_size
# Out:
# 11589

# %%
encoded_text=token.texts_to_sequences(text)

# %%
max_length=200
x=sequence.pad_sequences(encoded_text,maxlen=max_length,padding='pre')
x
# Out:
# array([[    0,     0,     0, ...,   104,   453,   844],
#        [    0,     0,     0, ...,   343,    25,   114],
#        [    0,     0,     0, ...,   211,   221,  1417],
#        ...,
#        [    0,     0,     0, ...,   959, 11583, 11584],
#        [    0,     0,     0, ...,  1189,    46,    34],
#        [    0,     0,     0, ...,    12,     5,  1477]], dtype=int32)

# %%
x.shape
# Out:
# (5000, 200)

# %%
y=df['labels']
y.head()
# Out:
# 644295    0
# 468304    0
# 669586    0
# 248227    0
# 664507    0
# Name: labels, dtype: int64

# %%
y.value_counts()
# Out:
# 0    2500
# 4    2500
# Name: labels, dtype: int64

# %%
y=y.map({0:0,4:1})
y.shape
# Out:
# (5000,)

# %%
y.value_counts()
# Out:
# 0    2500
# 1    2500
# Name: labels, dtype: int64

# %% [markdown]
# # ****Model Training****

# %% [markdown]
# # ANN

# %%
vec_size=500
nn=models.Sequential([
    
    layers.Embedding(vocab_size,vec_size,input_length=max_length),
    layers.Conv1D(64,8,activation='relu'),
    layers.MaxPooling1D(2),
    layers.Dropout(0.8),
    
    layers.Dense(40,activation='relu'),
    layers.Dropout(0.9),
    
    layers.Dense(29,activation='relu'),
    layers.GlobalMaxPooling1D(),
    
    layers.Dense(1,activation='sigmoid')
    
    
    ])

# %%
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 200, 500)          5794500
# _________________________________________________________________
# conv1d (Conv1D)              (None, 193, 64)           256064
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 96, 64)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 96, 64)            0
# _________________________________________________________________
# dense (Dense)                (None, 96, 40)            2600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 96, 40)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 96, 29)            1189
# _________________________________________________________________
# global_max_pooling1d (Global (None, 29)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 30
# =================================================================
# Total params: 6,054,383
# Trainable params: 6,054,383
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)
nn.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
nn.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=25)
# Out:
# Epoch 1/25
# 2022-11-14 08:01:19.514905: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-11-14 08:01:21.758185: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 110/110 [==============================] - 12s 14ms/step - loss: 0.7129 - accuracy: 0.5037 - val_loss: 0.6911 - val_accuracy: 0.5420
# Epoch 2/25
# 110/110 [==============================] - 1s 12ms/step - loss: 0.7007 - accuracy: 0.5083 - val_loss: 0.6902 - val_accuracy: 0.5327
# Epoch 3/25
# 110/110 [==============================] - 1s 11ms/step - loss: 0.6972 - accuracy: 0.5243 - val_loss: 0.6878 - val_accuracy: 0.5587
# Epoch 4/25
# 110/110 [==============================] - 1s 11ms/step - loss: 0.6916 - accuracy: 0.5477 - val_loss: 0.6901 - val_accuracy: 0.5180
# Epoch 5/25
# 110/110 [==============================] - 1s 11ms/step - loss: 0.6665 - accuracy: 0.6003 - val_loss: 0.6842 - val_accuracy: 0.5347
# Epoch 6/25
# 110/110 [==============================] - 1s 12ms/step - loss: 0.6092 - accuracy: 0.6637 - val_loss: 0.6594 - val_accuracy: 0.6020
# Epoch 7/25
# 110/110 [==============================] - 2s 16ms/step - loss: 0.5457 - accuracy: 0.7303 - val_loss: 0.6354 - val_accuracy: 0.6353
# Epoch 8/25
# 110/110 [==============================] - 1s 12ms/step - loss: 0.4510 - accuracy: 0.8014 - val_loss: 0.6294 - val_accuracy: 0.6453
# Epoch 9/25
# 110/110 [==============================] - 1s 12ms/step - loss: 0.3350 - accuracy: 0.8506 - val_loss: 0.6304 - val_accuracy: 0.6280
# Epoch 10/25
# 110/110 [==============================] - 1s 11ms/step - loss: 0.2779 - accuracy: 0.8889 - val_loss: 0.6260 - val_accuracy: 0.6407
# Epoch 11/25
# 110/110 [==============================] - 1s 11ms/step - loss: 0.2258 - accuracy: 0.9120 - val_loss: 0.6269 - val_accuracy: 0.6487
# Epoch 12/25
# 110/110 [==============================] - 1s 11ms/step - loss: 0.1802 - accuracy: 0.9274 - val_loss: 0.6469 - val_accuracy: 0.6360
# Epoch 13/25
# 110/110 [==============================] - 1s 11ms/step - loss: 0.1527 - accuracy: 0.9386 - val_loss: 0.6661 - val_accuracy: 0.6453
# Epoch 14/25
# 110/110 [==============================] - 1s 11ms/step - loss: 0.1223 - accuracy: 0.9543 - val_loss: 0.7032 - val_accuracy: 0.6513
# Epoch 15/25
# 110/110 [==============================] - 1s 13ms/step - loss: 0.1357 - accuracy: 0.9534 - val_loss: 0.6949 - val_accuracy: 0.6200
# Epoch 16/25
# 110/110 [==============================] - 1s 11ms/step - loss: 0.1162 - accuracy: 0.9543 - val_loss: 0.7218 - val_accuracy: 0.6693
# Epoch 17/25
# 110/110 [==============================] - 1s 12ms/step - loss: 0.1020 - accuracy: 0.9620 - val_loss: 0.7036 - val_accuracy: 0.6527
# Epoch 18/25
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0952 - accuracy: 0.9600 - val_loss: 0.7343 - val_accuracy: 0.6387
# Epoch 19/25
# 110/110 [==============================] - 1s 12ms/step - loss: 0.0834 - accuracy: 0.9649 - val_loss: 0.7583 - val_accuracy: 0.6453
# Epoch 20/25
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0788 - accuracy: 0.9697 - val_loss: 0.7801 - val_accuracy: 0.6467
# Epoch 21/25
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0759 - accuracy: 0.9723 - val_loss: 0.7700 - val_accuracy: 0.6307
# Epoch 22/25
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0719 - accuracy: 0.9731 - val_loss: 0.8310 - val_accuracy: 0.6440
# Epoch 23/25
# 110/110 [==============================] - 1s 12ms/step - loss: 0.0833 - accuracy: 0.9677 - val_loss: 0.7893 - val_accuracy: 0.6467
# Epoch 24/25
# 110/110 [==============================] - 1s 12ms/step - loss: 0.0676 - accuracy: 0.9714 - val_loss: 0.7888 - val_accuracy: 0.6420
# Epoch 25/25
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0655 - accuracy: 0.9743 - val_loss: 0.8210 - val_accuracy: 0.6313

# %%
nn.evaluate(x_train,y_train)
# Out:
# 110/110 [==============================] - 0s 3ms/step - loss: 0.0856 - accuracy: 0.9800
# [0.08559820055961609, 0.9800000190734863]

# %%
nn.evaluate(x_test,y_test)
# Out:
# 47/47 [==============================] - 0s 3ms/step - loss: 0.8210 - accuracy: 0.6313
# [0.8210312724113464, 0.6313333511352539]

# %%
x_test=np.array(x_test)
x_test
# Out:
# array([[    0,     0,     0, ..., 10745,    34,    50],
#        [    0,     0,     0, ...,  7331,     9,   108],
#        [    0,     0,     0, ...,    43,    26,   254],
#        ...,
#        [    0,     0,     0, ...,  2603,     9,    24],
#        [    0,     0,     0, ...,   130,   150,    89],
#        [    0,     0,     0, ...,  4481,    87,    42]], dtype=int32)

# %%
y_train
# Out:
# 1539043    1
# 1256874    1
# 1157767    1
# 1234301    1
# 190275     0
#           ..
# 949826     1
# 1316133    1
# 1151206    1
# 1367784    1
# 1380763    1
# Name: labels, Length: 3500, dtype: int64

# %%
preds=nn.predict(x_test)
preds=(preds>0.5)
preds[:5]
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True]])

# %%
def get_encoded(x):
    x=token.texts_to_sequences(x)
    x=sequence.pad_sequences(x,maxlen=max_length,padding='pre')
    return x

# %%
h=['he is a cute boy who loves to help others']
h = get_encoded(h)
nn.predict(h)
# Out:
# array([[0.95499855]], dtype=float32)

# %%
h = ['I hate you']
h = get_encoded(h)
nn.predict(h)
# Out:
# array([[0.19985792]], dtype=float32)

# %% [markdown]
# # RNN

# %%
model = keras.Sequential()
model.add(layers.Embedding(input_dim=1000, output_dim=64))

# The output of GRU will be a 3D tensor of shape (batch_size, timesteps, 256)
model.add(layers.GRU(256, return_sequences=True))

# The output of SimpleRNN will be a 2D tensor of shape (batch_size, 128)
model.add(layers.SimpleRNN(128))

model.add(layers.Dense(10))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 64)          64000
# _________________________________________________________________
# gru (GRU)                    (None, None, 256)         247296
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, 128)               49280
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 361,866
# Trainable params: 361,866
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=25)
# Out:
# Epoch 1/25
# 110/110 [==============================] - 28s 230ms/step - loss: 3.5268 - accuracy: 0.1254 - val_loss: 3.5149 - val_accuracy: 0.0193
# Epoch 2/25
# 110/110 [==============================] - 25s 231ms/step - loss: 3.2578 - accuracy: 0.1003 - val_loss: 2.7949 - val_accuracy: 0.4500
# Epoch 3/25
# 110/110 [==============================] - 25s 227ms/step - loss: 2.7143 - accuracy: 0.0731 - val_loss: 2.8260 - val_accuracy: 0.1440
# Epoch 4/25
# 110/110 [==============================] - 26s 236ms/step - loss: 4.0888 - accuracy: 0.0851 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 110/110 [==============================] - 30s 276ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 110/110 [==============================] - 24s 220ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 7/25
# 110/110 [==============================] - 29s 262ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 8/25
# 110/110 [==============================] - 24s 222ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 9/25
# 110/110 [==============================] - 24s 223ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 10/25
# 110/110 [==============================] - 25s 229ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 11/25
# 110/110 [==============================] - 24s 220ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 12/25
# 110/110 [==============================] - 25s 226ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 13/25
# 110/110 [==============================] - 25s 225ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 14/25
# 110/110 [==============================] - 25s 226ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 15/25
# 110/110 [==============================] - 25s 229ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 16/25
# 110/110 [==============================] - 24s 222ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 17/25
# 110/110 [==============================] - 24s 220ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 18/25
# 110/110 [==============================] - 25s 223ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 19/25
# 110/110 [==============================] - 25s 224ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 20/25
# 110/110 [==============================] - 24s 217ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 21/25
# 110/110 [==============================] - 25s 228ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 22/25
# 110/110 [==============================] - 25s 227ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 23/25
# 110/110 [==============================] - 25s 225ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 24/25
# 110/110 [==============================] - 24s 221ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00
# Epoch 25/25
# 110/110 [==============================] - 24s 217ms/step - loss: 7.6904 - accuracy: 0.0000e+00 - val_loss: 7.7639 - val_accuracy: 0.0000e+00

# %%
model.evaluate(x_train,y_train)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(penalty="l2",random_state=42,C=0.01)
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)

print("Training Accuracy",clf.score(x_train, y_train))
print("Testing Accuracy",clf.score(x_test,y_pred))
# Out:
# Training Accuracy 0.504
# Testing Accuracy 1.0
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
